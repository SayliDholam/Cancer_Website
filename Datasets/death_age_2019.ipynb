# %%
import pandas as pd
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_20660\1895862228.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv("D:\Sayli_THAKUR\_SEM_2\_MiniProject_Sem2\Code_files\Cancer_Website\Datasets\death_age_2019.csv")
df
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1990
# 1     Afghanistan  AFG  1991
# 2     Afghanistan  AFG  1992
# 3     Afghanistan  AFG  1993
# 4     Afghanistan  AFG  1994
# ...           ...  ...   ...
# 6835     Zimbabwe  ZWE  2015
# 6836     Zimbabwe  ZWE  2016
# 6837     Zimbabwe  ZWE  2017
# 6838     Zimbabwe  ZWE  2018
# 6839     Zimbabwe  ZWE  2019
#
#       Deaths - Neoplasms - Sex: Both - Age: 70+ years (Rate)  \
# 0                                               1021.49
# 1                                               1013.76
# 2                                               1007.83
# 3                                               1006.57
# 4                                               1006.36
# ...                                                 ...
# 6835                                            1340.31
# 6836                                            1336.60
# 6837                                            1333.76
# 6838                                            1330.36
# 6839                                            1327.74
#
#       Deaths - Neoplasms - Sex: Both - Age: 50-69 years (Rate)  \
# 0                                                407.23
# 1                                                404.51
# 2                                                402.69
# 3                                                404.42
# 4                                                407.33
# ...                                                 ...
# 6835                                             465.15
# 6836                                             464.27
# 6837                                             461.89
# 6838                                             458.79
# 6839                                             455.85
#
#       Deaths - Neoplasms - Sex: Both - Age: 15-49 years (Rate)  \
# 0                                                 43.62
# 1                                                 40.53
# 2                                                 37.17
# 3                                                 35.72
# 4                                                 35.46
# ...                                                 ...
# 6835                                              34.03
# 6836                                              34.77
# 6837                                              35.27
# 6838                                              35.75
# 6839                                              36.22
#
#       Deaths - Neoplasms - Sex: Both - Age: 5-14 years (Rate)  \
# 0                                                  9.37
# 1                                                  9.46
# 2                                                  9.74
# 3                                                  9.83
# 4                                                  9.56
# ...                                                 ...
# 6835                                               2.50
# 6836                                               2.68
# 6837                                               2.77
# 6838                                               2.80
# 6839                                               2.75
#
#       Deaths - Neoplasms - Sex: Both - Age: Under 5 (Rate)  \
# 0                                                 21.33
# 1                                                 18.70
# 2                                                 16.80
# 3                                                 16.53
# 4                                                 16.53
# ...                                                 ...
# 6835                                               2.64
# 6836                                               2.75
# 6837                                               2.75
# 6838                                               2.72
# 6839                                               2.71
#
#       Deaths - Neoplasms - Sex: Both - Age: Age-standardized (Rate)  \
# 0                                                159.96
# 1                                                158.46
# 2                                                157.39
# 3                                                157.57
# 4                                                158.03
# ...                                                 ...
# 6835                                             182.60
# 6836                                             182.42
# 6837                                             181.84
# 6838                                             181.36
# 6839                                             180.93
#
#       Deaths - Neoplasms - Sex: Both - Age: All Ages (Rate)
# 0                                                101.41
# 1                                                 93.71
# 2                                                 84.01
# 3                                                 79.04
# 4                                                 77.17
# ...                                                 ...
# 6835                                              79.28
# 6836                                              80.13
# 6837                                              80.77
# 6838                                              81.48
# 6839                                              82.29
#
# [6840 rows x 10 columns]

# %%
df.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    Deaths - Neoplasms - Sex: Both - Age: 70+ years (Rate)  \
# 0                                            1021.49
# 1                                            1013.76
# 2                                            1007.83
# 3                                            1006.57
# 4                                            1006.36
#
#    Deaths - Neoplasms - Sex: Both - Age: 50-69 years (Rate)  \
# 0                                             407.23
# 1                                             404.51
# 2                                             402.69
# 3                                             404.42
# 4                                             407.33
#
#    Deaths - Neoplasms - Sex: Both - Age: 15-49 years (Rate)  \
# 0                                              43.62
# 1                                              40.53
# 2                                              37.17
# 3                                              35.72
# 4                                              35.46
#
#    Deaths - Neoplasms - Sex: Both - Age: 5-14 years (Rate)  \
# 0                                               9.37
# 1                                               9.46
# 2                                               9.74
# 3                                               9.83
# 4                                               9.56
#
#    Deaths - Neoplasms - Sex: Both - Age: Under 5 (Rate)  \
# 0                                              21.33
# 1                                              18.70
# 2                                              16.80
# 3                                              16.53
# 4                                              16.53
#
#    Deaths - Neoplasms - Sex: Both - Age: Age-standardized (Rate)  \
# 0                                             159.96
# 1                                             158.46
# 2                                             157.39
# 3                                             157.57
# 4                                             158.03
#
#    Deaths - Neoplasms - Sex: Both - Age: All Ages (Rate)
# 0                                             101.41
# 1                                              93.71
# 2                                              84.01
# 3                                              79.04
# 4                                              77.17

# %%
df.columns
# Out:
# Index(['Entity', 'Code', 'Year',
#        'Deaths - Neoplasms - Sex: Both - Age: 70+ years (Rate)',
#        'Deaths - Neoplasms - Sex: Both - Age: 50-69 years (Rate)',
#        'Deaths - Neoplasms - Sex: Both - Age: 15-49 years (Rate)',
#        'Deaths - Neoplasms - Sex: Both - Age: 5-14 years (Rate)',
#        'Deaths - Neoplasms - Sex: Both - Age: Under 5 (Rate)',
#        'Deaths - Neoplasms - Sex: Both - Age: Age-standardized (Rate)',
#        'Deaths - Neoplasms - Sex: Both - Age: All Ages (Rate)'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6840 entries, 0 to 6839
# Data columns (total 10 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   Entity                                                         6840 non-null   object
#  1   Code                                                           6150 non-null   object
#  2   Year                                                           6840 non-null   int64
#  3   Deaths - Neoplasms - Sex: Both - Age: 70+ years (Rate)         6840 non-null   float64
#  4   Deaths - Neoplasms - Sex: Both - Age: 50-69 years (Rate)       6840 non-null   float64
#  5   Deaths - Neoplasms - Sex: Both - Age: 15-49 years (Rate)       6840 non-null   float64
#  6   Deaths - Neoplasms - Sex: Both - Age: 5-14 years (Rate)        6840 non-null   float64
#  7   Deaths - Neoplasms - Sex: Both - Age: Under 5 (Rate)           6840 non-null   float64
#  8   Deaths - Neoplasms - Sex: Both - Age: Age-standardized (Rate)  6840 non-null   float64
#  9   Deaths - Neoplasms - Sex: Both - Age: All Ages (Rate)          6840 non-null   float64
# dtypes: float64(7), int64(1), object(2)
# memory usage: 534.5+ KB

# %%
df.hist(figsize=(20, 20))
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()
